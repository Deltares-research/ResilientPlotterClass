# %% [markdown]
# ### 0. Packages

# %%
# Resilient Plotter Class
from resilientplotterclass import rpclass
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a19f5325-6c6f-4e46-bddd-29457d0d3c6d" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ### 1. Setting Guidelines

# %%
# File path guidelines
file_path_gls = 'morphopy_guidelines.json'

# Set guidelines
rpc = rpclass(file_path_gls)

# Set guidelines
rpc.set_guidelines(file_path_gls)

# Print guidelines
rpc.print_guidelines()
# Out:
# <style type="text/css">
# #T_b29a0 th {
#   text-align: center;
# }
# #T_b29a0 thead {
#   border-bottom: 2px solid black;
# }
# #T_b29a0 caption {
#   font-weight: bold;
# }
# #T_b29a0_row0_col0, #T_b29a0_row0_col1, #T_b29a0_row0_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_b29a0">
#   <caption>Metadata</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b29a0_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_b29a0_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_b29a0_level0_col2" class="col_heading level0 col2" >author(s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b29a0_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_b29a0_row0_col0" class="data row0 col0" >Morphopy guidelines</td>
#       <td id="T_b29a0_row0_col1" class="data row0 col1" >2024-10-25</td>
# ...

# %%
rpc.get_guidelines()['data_type']['bathymetry'][']
# Out:
# {'pcolormesh': {'cmap': 'bathymetry',
#   'center': False,
#   'zorder': 1,
#   'cbar_kwargs': {'label': 'Bathymetry [m]'},
#   'append_axes_kwargs': {'position': 'right', 'size': '5%', 'pad': 0.05}},
#  'imshow': {'cmap': 'bathymetry',
#   'center': False,
#   'zorder': 1,
#   'cbar_kwargs': {},
#   'append_axes_kwargs': {'position': 'right', 'size': '5%', 'pad': 0.05}},
#  'scatter': {'edgecolor': 'none',
#   'cmap': 'bathymetry',
#   'zorder': 1,
#   'cbar_kwargs': {},
#   'append_axes_kwargs': {'position': 'right', 'size': '5%', 'pad': 0.05}},
#  'contourf': {'cmap': 'bathymetry',
#   'center': False,
#   'levels': 10,
#   'zorder': 1,
#   'cbar_kwargs': {},
#   'append_axes_kwargs': {'position': 'right', 'size': '5%', 'pad': 0.05}},
#  'contour': {'cmap': 'bathymetry_contour',
#   'center': False,
#   'zorder': 1,
#   'levels': 10,
#   'append_axes_kwargs': {'position': 'right', 'size': '5%', 'pad': 0.05}}}

# %% [markdown]
# ###  2. Using guidelines
